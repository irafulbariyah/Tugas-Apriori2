# %%
import numpy as np
import pandas as pd
from apyori import apriori

# %%
store_data = pd.read_excel ('E:/KULIAH/SEMESTER 6/data mining/apyori/data.xls')

# %%
store_data.head()
# Out:
#   Barang 1 Barang 2 Barang 3 Barang 4 Barang 5 Barang 6
# 0     Wine    Chips    Bread   Butter     Milk    Apple
# 1     Wine      NaN    Bread   Butter     Milk      NaN
# 2      NaN      NaN    Bread   Butter     Milk      NaN
# 3      NaN    Chips      NaN      NaN      NaN    Apple
# 4     Wine    Chips    Bread   Butter     Milk    Apple

# %%
store_data.tail()
# Out:
#    Barang 1 Barang 2 Barang 3 Barang 4 Barang 5 Barang 6
# 17      NaN    Chips      NaN   Butter     Milk    Apple
# 18     Wine    Chips    Bread   Butter     Milk    Apple
# 19     Wine      NaN    Bread   Butter     Milk    Apple
# 20     Wine    Chips    Bread      NaN     Milk    Apple
# 21      NaN    Chips      NaN      NaN      NaN      NaN

# %%
store_data.shape
# Out:
# (22, 6)

# %%
records =[]
for i in range(0, 22):
    records.append([str(store_data.values[i,j]) for j in range(0,6)])

# %%
association_rules = apriori(records, min_support=0.25, min_confidence=0.8, min_lift=1.5, min_lenght=5)
association_results = list(association_rules)

# %%
print(len(association_rules))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-a193a5e5a1a9> in <module>
# ----> 1 print(len(association_rules))
#
# TypeError: object of type 'generator' has no len()

# %%
print(len(association_results))
# Out:
# 0

# %%
print(association_results[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-d4cfcde839ad> in <module>
# ----> 1 print(association_results[0])
#
# IndexError: list index out of range

# %%
print(association_results[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-d4cfcde839ad> in <module>
# ----> 1 print(association_results[0])
#
# IndexError: list index out of range

# %%
print(association_results[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-7e16947ff0b7> in <module>
# ----> 1 print(association_results[2])
#
# IndexError: list index out of range

# %%
association_rules = apriori(records, min_support=0.20, min_confidence=0.10, min_lift=1.0, min_lenght=5)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 95

# %%
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'Apple'}), support=0.6818181818181818, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Apple'}), confidence=0.6818181818181818, lift=1.0)])

# %%
result =[]
for item in association_results:
    pair = item[0]
    items = [x for x in pair]
    
    value0 = str(items[0])
    value1 = str(items[1])
    value2 = str(items[1])[:6]
    value3 = str(items[2][0][2])[:6]
    value4 = str(items[2][0][3])[:6]
    
    
    rows = (value0,value1,value2,value3,value4)
    
    results.append(rows)
    
    label = ['title1', 'title2', 'support', 'confidence', 'lift']

    store_suggestion = pd.DataFrame.from_records(result,columns=label)
    
    print(store_suggestion)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-251426be3f6e> in <module>
#       5
#       6     value0 = str(items[0])
# ----> 7     value1 = str(items[1])
#       8     value2 = str(items[1])[:6]
#       9     value3 = str(items[2][0][2])[:6]
#
# IndexError: list index out of range

# %%
results = []
for item in association_results:
    pair = item[0]
    items = [x for x in pair]
    
    value0 = str(items[0])
    value1 = str(items[1])
    value2 = str(item[1])[:6]
    value3 = str(item[2][0][2])[:6]
    value4 = str(item[2][0][3])[:6]
    
    rows = (value0, value1, value2, value3, value4)
    
    results.append(rows)
    
    label = ['title1'], ['title2'],['support'], ['confidence'],['lift']
    
    store_suggestion = pd.DataFrame.from_records(results,columns=label)
    
    print(store_suggestion)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-7e0436e8df42> in <module>
#       5
#       6     value0 = str(items[0])
# ----> 7     value1 = str(items[1])
#       8     value2 = str(item[1])[:6]
#       9     value3 = str(item[2][0][2])[:6]
#
# IndexError: list index out of range

# %%
association_rules = apriori(records, min_support=0.30, min_confidence=0.10, min_lift=1.0, min_lenght=3)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 69

# %%
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'Apple'}), support=0.6818181818181818, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Apple'}), confidence=0.6818181818181818, lift=1.0)])

# %%
results = []
for item in association_results:
    pair = item[0]
    items = [x for x in pair]
    
    value0 = str(items[0])
    value1 = str(items[1])
    value2 = str(item[1])[:6]
    value3 = str(item[2][0][2])[:6]
    value4 = str(item[2][0][3])[:6]
    
    rows = (value0, value1, value2, value3, value4)
    
    results.append(rows)
    
    label = ['title1'], ['title2'],['support'], ['confidence'],['lift']
    
    store_suggestion = pd.DataFrame.from_records(results,columns=label)
    
    print(store_suggestion)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-7e0436e8df42> in <module>
#       5
#       6     value0 = str(items[0])
# ----> 7     value1 = str(items[1])
#       8     value2 = str(item[1])[:6]
#       9     value3 = str(item[2][0][2])[:6]
#
# IndexError: list index out of range

# %%
association_rules = apriori(records, min_support=0.12, min_confidence=0.9, min_lift=1.8, min_lenght=2)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 0

# %%
association_rules = apriori(records, min_support=0.15, min_confidence=0.15, min_lift=1.5, min_lenght=2)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 0

# %%
association_rules = apriori(records, min_support=0.20, min_confidence=0.8, min_lift=1.5, min_lenght=2)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 0

# %%
association_rules = apriori(records, min_support=0.10, min_confidence=0.8, min_lift=1.5, min_lenght=8)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 0

# %%
association_rules = apriori(records, min_support=0.20, min_confidence=0.10, min_lift=1.10, min_lenght=8)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 45

# %%
results = []
for item in association_results:
    pair = item[0]
    items = [x for x in pair]
    
    value0 = str(items[0])
    value1 = str(items[1])
    value2 = str(item[1])[:6]
    value3 = str(item[2][0][2])[:6]
    value4 = str(item[2][0][3])[:6]
    
    rows = (value0, value1, value2, value3, value4)
    
    results.append(rows)
    
    label = ['title1'], ['title2'],['support'], ['confidence'],['lift']
    
    store_suggestion = pd.DataFrame.from_records(results,columns=label)
    
    print(store_suggestion)
# Out:
#   (title1,) (title2,) (support,) (confidence,) (lift,)
# 0     Apple     Bread     0.5454           0.8     1.1
#   (title1,) (title2,) (support,) (confidence,) (lift,)
# 0     Apple     Bread     0.5454           0.8     1.1
# 1     Bread    Butter     0.5909        0.8125  1.1916
#   (title1,) (title2,) (support,) (confidence,) (lift,)
# 0     Apple     Bread     0.5454           0.8     1.1
# 1     Bread    Butter     0.5909        0.8125  1.1916
# 2      Wine     Bread     0.5909        0.8125  1.1171
#   (title1,) (title2,) (support,) (confidence,) (lift,)
# 0     Apple     Bread     0.5454           0.8     1.1
# 1     Bread    Butter     0.5909        0.8125  1.1916
# 2      Wine     Bread     0.5909        0.8125  1.1171
# 3      Milk    Butter     0.5909        0.8666  1.1215
#   (title1,) (title2,) (support,) (confidence,) (lift,)
# 0     Apple     Bread     0.5454           0.8     1.1
# 1     Bread    Butter     0.5909        0.8125  1.1916
# ...

# %%
store_suggestion.describe()
# Out:
#        (title1,) (title2,) (support,) (confidence,) (lift,)
# count         45        45         45            45      45
# unique         6         7         10            21      21
# top        Apple      Milk     0.2727        0.5625     1.1
# freq          18        11          9             6       5

# %%
store_suggestion.to_excel('E:/KULIAH/SEMESTER 6/data mining/apyori/data_output7.xls')
